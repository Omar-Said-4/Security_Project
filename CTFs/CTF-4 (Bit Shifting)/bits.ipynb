# %%
import string
import matplotlib.pyplot as plt
import re
from collections import Counter
# %matplotlib qt

# %%
with open("bits.txt", "r") as f:
    text = f.read().strip()


print(text)
# Out:
# $2ï¿½67ï¿½0ï¿½2;ï¿½ï¿½1ï¿½ï¿½ï¿½ï¿½:7ï¿½34ï¿½2ï¿½ï¿½ï¿½37ï¿½2ï¿½9ï¿½ï¿½ï¿½1ï¿½0ï¿½62ï¿½3ï¿½ï¿½*44ï¿½ï¿½4ï¿½ï¿½5:ï¿½ï¿½34ï¿½62ï¿½:2ï¿½::7ï¿½6ï¿½ï¿½ï¿½ï¿½4ï¿½67ï¿½3ï¿½ï¿½ï¿½ï¿½30ï¿½ï¿½1ï¿½3=ï¿½ï¿½ï¿½4ï¿½/ï¿½94ï¿½ï¿½ï¿½ï¿½

# %%
text="$2�67�0�2;��1����:7�34�2���37�2�9���1�0�62�3��*44��4��5:��34�62�:2�::7�6����4�67�3����30��1�3=���4�/�94����"
for i in range(9):
    for char in text:
        new_char = chr((ord(char) >> i))
        print(new_char, end="")
    print("\nnext\n",i,"\n")
# Out:
# $2�67�0�2;��1����:7�34�2���37�2�9���1�0�62�3��*44��4��5:��34�62�:2�::7�6����4�67�3����30��1�3=���4�/�94����
# next
#  0
#
# 翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾翾
# next
#  1
#
# 㿿㿿㿿㿿㿿㿿㿿㿿
# 㿿㿿㿿㿿㿿㿿㿿㿿㿿㿿㿿㿿
# next
#  2
#
# ῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿῿
# next
#  3
#
# ࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿࿿
# next
#  4
#
# ߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿߿
# next
#  5
#
# ϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿϿ
# next
#  6
#
# ǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿǿ
# next
#  7
#
# ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ
# next
#  8
